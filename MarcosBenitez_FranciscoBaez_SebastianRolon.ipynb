# %% [markdown]
# # ***INTEGRANTES:***
#
#
#
# 1.   Marcos Benítez 4.661.558
# 2.   Francisco Baez 5.244.084
# 3.   Sebastian Rolon 4.613.123

# %%
import numpy as np
import pandas as pd

# %%
academico = pd.read_excel('/content/drive/MyDrive/IA - TP/archivo_final.xlsx')

# %%
academicocb = academico[academico['Cod.Curso']<5]#estoy filtrando las materias de cursos basicos
academicocb['Aprobado']=='S'[:1]
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 81835     True
# 81836     True
# 81837     True
# 81838     True
# 81839     True
# Name: Aprobado, Length: 37911, dtype: bool

# %%
academicocb['Aprobado10']=academicocb['Aprobado']=='S'
academicocb
# Out:
# <ipython-input-42-046c8ac9970c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   academicocb['Aprobado10']=academicocb['Aprobado']=='S'
#        Cod.Asign      Asignatura Cod.Car.Sec  Cod.Curso  Convocatoria  Anho  \
# 0          13001        FISICA 1  ELE-PLS13           1             1  2021
# 1          13001        FISICA 1  MCT-PLS13           1             1  2021
# 2          13001        FISICA 1  CIV-PLS13           1             1  2021
# 3          13001        FISICA 1  CIV-PLS13           1             1  2021
# 4          13001        FISICA 1  CIV-PLS13           1             1  2021
# ...          ...             ...         ...        ...           ...   ...
# 81835      23716  DIBUJO TECNICO  MCT-PLS23           1             1  2023
# 81836      23716  DIBUJO TECNICO  MCT-PLS23           1             1  2023
# 81837      23716  DIBUJO TECNICO  MCT-PLS23           1             1  2023
# 81838      23716  DIBUJO TECNICO  MCT-PLS23           1             1  2023
# 81839      23716  DIBUJO TECNICO  MCT-PLS23           1             1  2023
#
#        Semestre  Doc.Firma Aprobado  Anho.Firma  Primer.Par  Segundo.Par  \
# 0             1      32304        S        2021           5            0
# 1             1          0        N           0           0            0
# 2             1          0        N           0           0            0
# 3             1          0        N           0           0            0
# 4             1          0        N           0           0            0
# ...         ...        ...      ...         ...         ...          ...
# 81835         2      35760        S        2023          20           33
# 81836         2      35760        S        2023          18           32
# 81837         2      35760        S        2023          22           33
# 81838         2      36026        S        2023          12           11
# 81839         2      35760        S        2023          20           19
#
#        Tercer.Par  AOT  Asis  Requisito  Primer.Rec  Segundo.Rec  NOTA.FINAL  \
# 0               0    3     1        1.0          32            0         2.0
# 1               0    0     1        0.0           0            0         NaN
# 2               0    0     1        0.0           0            0         NaN
# 3               0    0     1        0.0           0            0         NaN
# 4               0    2     1        1.0           0            0         NaN
# ...           ...  ...   ...        ...         ...          ...         ...
# 81835           0    9     1        1.0           0            0         5.0
# 81836           0    9     1        1.0           0            0         4.0
# 81837           0    9     1        1.0           0            0         5.0
# 81838           0    9     1        1.0          44            0         3.0
# 81839           0    9     1        1.0           0            0         5.0
#
#        Aprobado10
# 0            True
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 81835        True
# 81836        True
# 81837        True
# 81838        True
# 81839        True
#
# [37911 rows x 20 columns]

# %%
df = pd.DataFrame(academicocb)

# Agrupamos los datos por puntaje y resultado y contamos las ocurrencias
grouped = df.groupby(['Primer.Par', 'Aprobado10']).size().unstack(fill_value=0)

# Convertimos los conteos a porcentajes
percentage_grouped = grouped.div(grouped.sum(axis=1), axis=0) * 100

# Creamos el gráfico de barras
percentage_grouped.plot(kind='bar', stacked=True, color =['Red','Lightgreen'] )

# Configuramos las etiquetas y el título
plt.xlabel('Puntaje Primer Parcial')
plt.ylabel('Porcentaje')
plt.title('% de Aprobados y No aprobados por Puntaje de primer parcial')
plt.legend(labels=['No aprobado', 'Aprobado'],bbox_to_anchor=(1.3, 1), loc='upper right')

# Mostramos el gráfico
plt.show()

# %%
df = pd.DataFrame(academicocb)

# Agrupamos los datos por puntaje y resultado y contamos las ocurrencias
grouped = df.groupby(['Segundo.Par', 'Aprobado10']).size().unstack(fill_value=0)

# Convertimos los conteos a porcentajes
percentage_grouped = grouped.div(grouped.sum(axis=1), axis=0) * 100

# Creamos el gráfico de barras
percentage_grouped.plot(kind='bar', stacked=True, color =['Red','Lightgreen'] )

# Configuramos las etiquetas y el título
plt.xlabel('Puntaje Segundo Parcial')
plt.ylabel('Porcentaje')
plt.title('% de Aprobados y No aprobados por Puntaje de segundo parcial')
plt.legend(labels=['No aprobado', 'Aprobado'],bbox_to_anchor=(1.3, 1), loc='upper right')

# Mostramos el gráfico
plt.show()

# %%
df = pd.DataFrame(academicocb)

# Agrupamos los datos por puntaje y resultado y contamos las ocurrencias
grouped = df.groupby(['AOT', 'Aprobado10']).size().unstack(fill_value=0)

# Convertimos los conteos a porcentajes
percentage_grouped = grouped.div(grouped.sum(axis=1), axis=0) * 100

# Creamos el gráfico de barras
percentage_grouped.plot(kind='bar', stacked=True, color =['Red','Lightgreen'] )

# Configuramos las etiquetas y el título
plt.xlabel('Puntaje de Taller')
plt.ylabel('Porcentaje')
plt.title('% de Aprobados y No aprobados por Puntaje de taller')
plt.legend(labels=['No aprobado', 'Aprobado'],bbox_to_anchor=(1.3, 1), loc='upper right')

# Mostramos el gráfico
plt.show()

# %%
academicocb['FIRMA']=academicocb['Primer.Par']+academicocb['Segundo.Par']+academicocb['AOT']
# Out:
# <ipython-input-81-3ddb9c62db06>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   academicocb['FIRMA']=academicocb['Primer.Par']+academicocb['Segundo.Par']+academicocb['AOT']

# %%
df = pd.DataFrame(academicocb)

# Agrupamos los datos por puntaje y resultado y contamos las ocurrencias
grouped = df.groupby(['FIRMA', 'Aprobado10']).size().unstack(fill_value=0)

# Convertimos los conteos a porcentajes
percentage_grouped = grouped.div(grouped.sum(axis=1), axis=0) * 100

# Creamos el gráfico de barras
ax=percentage_grouped.plot(kind='bar', stacked=True, color =['Red','Lightgreen'] )
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, fontsize=5)


# Configuramos las etiquetas y el título
plt.xlabel('FIRMA (P1+P2+Ta)')
plt.ylabel('Porcentaje')
plt.title('% de Aprobados y No aprobados por FIRMA (P1+P2+Ta)')
plt.legend(labels=['No aprobado', 'Aprobado'],bbox_to_anchor=(1.3, 1), loc='upper right')

# Mostramos el gráfico
plt.show()
